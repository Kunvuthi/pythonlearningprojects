# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("csv_files/uk_mean_temperature.csv")
print(df.head())
# Out:
#    heathrow_mean_temp  leeming_mean_temp  camborne_mean_temp  hurn_mean_temp  \
# 0                14.6               10.0                10.7           12.35
# 1                 8.8                6.4                 8.9            8.25
# 2                 7.2                6.5                 8.1            8.15
# 3                 7.3                7.8                 8.2            6.70
# 4                10.1               13.2                 9.8           10.45
#
#    leuchars_mean_temp
# 0                8.70
# 1                4.75
# 2                6.50
# 3                9.30
# 4               11.55

# %%
sns.kdeplot(df["heathrow_mean_temp"], shade=True)
sns.kdeplot(df["leeming_mean_temp"], shade=True)
sns.kdeplot(df["camborne_mean_temp"], shade=True)

# %%
sns.kdeplot(df["hurn_mean_temp"], shade=True)
sns.kdeplot(df["leuchars_mean_temp"], shade=True)
